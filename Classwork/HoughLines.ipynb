# %% [markdown]
# ## Hough Lines

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
color = cv2.imread('Data/1.jpg')
color = cv2.cvtColor(color,cv2.COLOR_BGR2RGB)

# %%
gray = cv2.imread ('DATA/1.jpg',0)

# %%
blur = cv2.GaussianBlur(gray,(5,5),0)

# %%
edge = cv2.Canny(blur,50,150)

# %%
lines = cv2.HoughLines(edge, rho=1, theta=np.pi/180,threshold=80,minLineLengt)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 lines = cv2.HoughLinesP(edge, 1,np.pi/180,100,minLineLenght=50,maxLineGap=10)
#
# error: OpenCV(4.5.5) :-1: error: (-5:Bad argument) in function 'HoughLinesP'
# > Overload resolution failed:
# >  - 'minLineLenght' is an invalid keyword argument for HoughLinesP()
# >  - 'minLineLenght' is an invalid keyword argument for HoughLinesP()
